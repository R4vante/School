# %%
from DOE import Anova_Block, Anova_NoBlock

# %% [markdown]
# ![](attachment:image.png)
# ![image.png](attachment:image-2.png)

# %%
n = 4
a = 3
alpha = 0.05
Data_nb = Anova_NoBlock("opdrachten.xlsx", alpha, n, a)

# %%
df, df_melt, names, mean = Data_nb.import_df("13.49")

# %%
Data_nb.boxplot()

# %%
df_melt, anova_table, pvalue, lsd, mse = Data_nb.anova()
# Out:
# H0 accepted
# 1-2: no significant difference
# 1-3: no significant difference
# 2-3: no significant difference

# %%
anova_table
# Out:
#              sum_sq   df         F    PR(>F)
# treatment  0.001400  2.0  0.278453  0.763244
# Residual   0.022625  9.0       NaN       NaN

# %% [markdown]
# Uit de anova analyse blijkt dat er geen significant verschil is tussen de treatments. De nulhypothese wordt dus geaccepteerd.

# %%
Data_b = Anova_Block("opdrachten.xlsx", alpha, n, a)

# %%
df, df_melt, mean_row, mean_block = Data_b.melt("13.49")

# %%
df_melt, anova_table, pvalue, lsd = Data_b.anova()
# Out:
# H0 accepted
# 1-2: no significant difference
# 1-3: no significant difference
# 2-3: SIGNIFICANT DIFFERENCE!

# %%
anova_table
# Out:
#              sum_sq   df          F    PR(>F)
# treatment  0.001400  2.0   3.000000  0.125000
# block      0.021225  3.0  30.321429  0.000506
# Residual   0.001400  6.0        NaN       NaN

# %% [markdown]
# Uit de anova analyse blijkt dat er geen significant verschil is tussen de treatments, echter zegt de LSD methode dat er wel een verschil is tussen de treatments 2 en 3

# %%
Data_b.res_plot()

# %% [markdown]
# De patronen in de residual-plots lijken random, echter lijkt er in de residuals over het gemiddele een verband mogelijk. Daarom kan er geen conclusie getrokken worden.
