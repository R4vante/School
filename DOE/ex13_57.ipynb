# %%
from DOE import Anova_Block, Anova_NoBlock
from scipy import stats
import numpy as np

# %% [markdown]
# ![image.png](attachment:image.png)
#
# ![image.png](attachment:image-2.png)

# %% [markdown]
# # Anova zonder blokken

# %%
n = 5
a = 3
alpha = 0.01
Data_nb = Anova_NoBlock("opdrachten.xlsx", alpha, n, a)

# %%
df, df_melt, names, mean = Data_nb.import_df("13.57")

# %%
Data_nb.boxplot()

# %%
df_melt, anova_table, pvalue, lsd, mse = Data_nb.anova()
# Out:
# H0 rejected
# 1-2: no significant difference
# 1-3: SIGNIFICANT DIFFERENCE!
# 2-3: no significant difference

# %%
anova_table
# Out:
#             sum_sq    df         F    PR(>F)
# treatment  16480.0   2.0  7.841396  0.006635
# Residual   12610.0  12.0       NaN       NaN

# %%
Data_nb.res_plot()

# %%
Data_nb.norm_plot()

# %%
Data_b = Anova_Block("opdrachten.xlsx", alpha, n, a)

# %%
df, df_melt, mean_row, mean_block = Data_b.melt("13.57")

# %%
df_melt, anova_table, pvalue, lsd = Data_b.anova()
# Out:
# H0 rejected
# 1-2: no significant difference
# 1-3: SIGNIFICANT DIFFERENCE!
# 2-3: no significant difference

# %%
anova_table
# Out:
#                  sum_sq   df         F    PR(>F)
# treatment  16480.000000  2.0  9.088235  0.008724
# block       5356.666667  4.0  1.477022  0.295476
# Residual    7253.333333  8.0       NaN       NaN

# %%
Data_b.res_plot()

# %%
std2 = df[1].values.std()
mean2 = mean[0]
t = stats.t.ppf(1-alpha/2, n, a)
xmin = mean2 - t*std2/(np.sqrt(n))
xmax = mean2 + t*std2/(np.sqrt(n))

mu = np.array([xmin, xmax])

print(mu)
# Out:
# [1190.67135177 1307.32864823]

# %% [markdown]
# # A en B
#
# Doordat $p = 0.008 < \alpha$ blijkt er volgens de anova analyse wel een significant verschil tussen de treatments.

# %% [markdown]
# # C
#
# Treatment 1 en 3 dus tussen 70 en 80 graden Celsius.

# %% [markdown]
# # D
#
# Alles ziet er in de residuals best random uit, dus er blijkt geen extra afhankelijkheid te zijn. Dus het is goei.
