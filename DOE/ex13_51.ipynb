# %%
from DOE import Anova_Block, Anova_NoBlock

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Anova zonder blokken

# %%
n = 5
a = 4
alpha = 0.05
Data_nb = Anova_NoBlock("opdrachten.xlsx", alpha, n, a)

# %%
df, df_melt, names, mean = Data_nb.import_df("13.51")

# %%
Data_nb.boxplot()

# %%
Data_nb.norm_plot()

# %%
df_melt, anova_table, pvalue, lsd, mse = Data_nb.anova()
# Out:
# H0 rejected
# 1-2: no significant difference
# 1-3: no significant difference
# 1-4: SIGNIFICANT DIFFERENCE!
# 2-3: no significant difference
# 2-4: SIGNIFICANT DIFFERENCE!
# 3-4: no significant difference

# %%
Data_b = Anova_Block("opdrachten.xlsx", alpha, n, a)

# %%
df, df_melt, mean_row, mean_block = Data_b.melt("13.51")

# %%
df_melt, anova_table, pvalue, lsd = Data_b.anova()
# Out:
# H0 rejected
# 1-2: no significant difference
# 1-3: SIGNIFICANT DIFFERENCE!
# 1-4: SIGNIFICANT DIFFERENCE!
# 2-3: SIGNIFICANT DIFFERENCE!
# 2-4: SIGNIFICANT DIFFERENCE!
# 3-4: no significant difference

# %%
df_melt
# Out:
#    block treatment  value  mean_row  mean_column  residual
# 0      1         1    0.7      0.84        0.850     1.295
# 1      2         1    0.8      0.84        1.025     1.220
# 2      3         1    0.8      0.84        1.350     0.895
# 3      4         1    0.9      0.84        1.700     0.645
# 4      5         1    1.0      0.84        6.500    -4.055
# 5      1         2    0.8      0.88        0.850     1.355
# 6      2         2    0.8      0.88        1.025     1.180
# 7      3         2    0.9      0.88        1.350     0.955
# 8      4         2    0.9      0.88        1.700     0.605
# 9      5         2    1.0      0.88        6.500    -4.095
# 10     1         3    0.9      1.92        0.850     0.415
# 11     2         3    1.0      1.92        1.025     0.340
# 12     3         3    1.7      1.92        1.350     0.715
# 13     4         3    2.0      1.92        1.700     0.665
# 14     5         3    4.0      1.92        6.500    -2.135
# 15     1         4    1.0      5.50        0.850    -3.065
# 16     2         4    1.5      5.50        1.025    -2.740
# 17     3         4    2.0      5.50        1.350    -2.565
# 18     4         4    3.0      5.50        1.700    -1.915
# 19     5         4   20.0      5.50        6.500    10.285

# %%
Data_b.res_plot()
