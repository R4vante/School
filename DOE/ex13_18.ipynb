# %%
from DOE import Anova_NoBlock
from scipy import stats
import numpy as np

# %% [markdown]
# ![image.png](attachment:image-3.png)
#
# ![image.png](attachment:image.png)
#
#
# # Kijk naar linker kolom a,b,c,d

# %%
alpha = 0.05
n = 8
a = 3
Data = Anova_NoBlock("opdrachten.xlsx", alpha, n, a)

# %%
df, df_melt, names, mean = Data.import_df("13.18")

# %%
df
# Out:
#          1       2       3
# 1  0.01211  0.0031  0.1562
# 2  0.01320  0.0006  0.2227
# 3  0.00110  0.0000  0.0953
# 4  0.00230  0.0000  0.8911
# 5  0.03910  0.0220  1.3892
# 6  0.00540  0.0019  0.0154
# 7  0.00030  0.0007  1.7916
# 8  0.00140  0.0000  0.1992

# %% [markdown]
# # A

# %%
Data.boxplot()

# %% [markdown]
# # Nulhypothese
#
# H0 $\mu_i = \mu$
#
# H1 $\mu_i \neq \mu$

# %%
df_melt, anova_table, pvalue, lsd, mse = Data.anova()
# Out:
# H0 rejected
# 1-2: no significant difference
# 1-3: SIGNIFICANT DIFFERENCE!
# 2-3: SIGNIFICANT DIFFERENCE!

# %%
anova_table
# Out:
#              sum_sq    df         F    PR(>F)
# treatment  1.848100   2.0  6.016491  0.008597
# Residual   3.225311  21.0       NaN       NaN

# %% [markdown]
# # B
#
# p-waarde = 0.008597

# %%
Data.meanplot()

# %% [markdown]
# # C

# %%
Data.res_plot()

# %% [markdown]
# Er is geen extra afhankelijk want de hoogtes in de residuals zijn willekeurig.

# %%
Data.norm_plot()

# %%
std2 = df[2].values.std()
mean2 = mean[1]
t = stats.t.ppf(1-alpha/2, n, a)
xmin = mean2 - t*std2/(np.sqrt(n))
xmax = mean2 + t*std2/(np.sqrt(n))

mu = np.array([xmin, xmax])

print(mu)
# Out:
# [-0.00969362  0.01676862]

# %% [markdown]
# # D
#
# Betrouwbaarheids interval:
#
# $$ -0,0097 \leq \mu \leq 0.0168$$
