# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
punten = [7, 6, 9, 9, 8, 5, 6, 6, 1, 8, 9, 8, 2, 7 , 7]

# %%
from matplotlib import colors


fig, ax = plt.subplots(1)
bp = ax.boxplot(punten, notch=True, patch_artist=True, vert=0, labels=("Punten Henk", ))
plt.setp(bp['boxes'], facecolor="pink")

plt.show()
